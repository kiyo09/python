# %% [markdown]
# # DataFrame

# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
# NFLのデータをサンプルとして使います。
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
# クリップボードから読み込むことが可能です。
nfl_frame = pd.read_clipboard()
nfl_frame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     403                         if cls is not object \
#     404                                 and callable(cls.__dict__.get('__repr__')):
# --> 405                             return _repr_pprint(obj, self, cycle)
#     406
#     407             return _default_pprint(obj, self, cycle)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     693     """A pprint that just redirects to the normal repr function."""
#     694     # Find newlines and replace them with p.break_()
# --> 695     output = repr(obj)
#     696     lines = output.splitlines()
#     697     with p.group():
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __repr__(self)
#     685             line_width=width,
#     686             max_colwidth=max_colwidth,
# --> 687             show_dimensions=show_dimensions,
#     688         )
#     689
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#     818                 line_width=line_width,
#     819             )
# --> 820             return formatter.to_string(buf=buf, encoding=encoding)
#     821
#     822     # ----------------------------------------------------------------------
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in to_string(self, buf, encoding)
#     914         encoding: Optional[str] = None,
#     915     ) -> Optional[str]:
# --> 916         return self.get_result(buf=buf, encoding=encoding)
#     917
#     918     def to_latex(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in get_result(self, buf, encoding)
#     521         """
#     522         with self.get_buffer(buf, encoding=encoding) as f:
# --> 523             self.write_result(buf=f)
#     524             if buf is None:
#     525                 return f.getvalue()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in write_result(self, buf)
#     823         else:
#     824
# --> 825             strcols = self._to_str_columns()
#     826             if self.line_width is None:  # no need to wrap around just print
#     827                 # the whole frame
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in _to_str_columns(self)
#     719         # may include levels names also
#     720
# --> 721         str_index = self._get_formatted_index(frame)
#     722
#     723         if not is_list_like(self.header) and not self.header:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in _get_formatted_index(self, frame)
#    1073
#    1074         # empty space for columns
# -> 1075         if self.show_col_idx_names:
#    1076             col_header = ["{x}".format(x=x) for x in self._get_column_name_list()]
#    1077         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in show_col_idx_names(self)
#    1041     @property
#    1042     def show_col_idx_names(self) -> bool:
# -> 1043         return all((self.has_column_names, self.show_index_names, self.header))
#    1044
#    1045     def _get_formatted_index(self, frame: "DataFrame") -> List[str]:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in has_column_names(self)
#    1033     @property
#    1034     def has_column_names(self) -> bool:
# -> 1035         return _has_names(self.frame.columns)
#    1036
#    1037     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in _has_names(index)
#    1805         return com.any_not_none(*index.names)
#    1806     else:
# -> 1807         return index.name is not None
#    1808
#    1809
#
# AttributeError: 'list' object has no attribute 'name'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732                 render_links=False,
#     733             )
# --> 734             return formatter.to_html(notebook=True)
#     735         else:
#     736             return None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     983         Klass = NotebookFormatter if notebook else HTMLFormatter
#     984         return Klass(self, classes=classes, border=border).get_result(
# --> 985             buf=buf, encoding=encoding
#     986         )
#     987
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in get_result(self, buf, encoding)
#     521         """
#     522         with self.get_buffer(buf, encoding=encoding) as f:
# --> 523             self.write_result(buf=f)
#     524             if buf is None:
#     525                 return f.getvalue()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in write_result(self, buf)
#     205
#     206     def write_result(self, buf: IO[str]) -> None:
# --> 207         buffer_put_lines(buf, self.render())
#     208
#     209     def _write_table(self, indent: int = 0) -> None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in render(self)
#     610         self.write("<div>")
#     611         self.write_style()
# --> 612         super().render()
#     613         self.write("</div>")
#     614         return self.elements
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in render(self)
#     192
#     193     def render(self) -> List[str]:
# --> 194         self._write_table()
#     195
#     196         if self.should_show_dimensions:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in _write_table(self, indent)
#     235
#     236         if self.fmt.header or self.show_row_idx_names:
# --> 237             self._write_header(indent + self.indent_delta)
#     238
#     239         self._write_body(indent + self.indent_delta)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in _write_header(self, indent)
#     369
#     370         if self.fmt.header:
# --> 371             self._write_col_header(indent + self.indent_delta)
#     372
#     373         if self.show_row_idx_names:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/html.py in _write_col_header(self, indent)
#     346                 # DataFrameFormatter class.
#     347                 if self.fmt.show_index_names:
# --> 348                     row.append(self.columns.name or "")
#     349                 else:
#     350                     row.append("")
#
# AttributeError: 'list' object has no attribute 'name'
