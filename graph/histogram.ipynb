# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
from numpy.random import randn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib inline

# %%
def randrange(n, vmin, vmax):
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 100
for c, m, zlow, zhigh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

# %%
dataset1= randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 2.,  2.,  8.,  9., 21., 25., 16.,  9.,  5.,  3.]),
#  array([-3.12445981, -2.54369798, -1.96293616, -1.38217433, -0.80141251,
#         -0.22065068,  0.36011114,  0.94087297,  1.52163479,  2.10239662,
#          2.68315844]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2, color='indianred')
# Out:
# (array([ 1.,  4.,  3., 11., 15., 11., 18.,  9.,  5.,  3.]),
#  array([-2.50648852, -2.03095918, -1.55542985, -1.07990052, -0.60437118,
#         -0.12884185,  0.34668748,  0.82221682,  1.29774615,  1.77327548,
#          2.24880482]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset2,color='indianred',edgecolor="black")
# Out:
# (array([ 1.,  4.,  3., 11., 15., 11., 18.,  9.,  5.,  3.]),
#  array([-2.50648852, -2.03095918, -1.55542985, -1.07990052, -0.60437118,
#         -0.12884185,  0.34668748,  0.82221682,  1.29774615,  1.77327548,
#          2.24880482]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed=True, alpha=0.5, bins=20)
plt.hist(dataset2, normed=True, alpha=0.5, bins=20)
# Out:
# /Users/ishizakikiyohiko/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """Entry point for launching an IPython kernel.
# /Users/ishizakikiyohiko/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# (array([0.05257299, 0.        , 0.05257299, 0.15771898, 0.15771898,
#         0.        , 0.26286496, 0.31543795, 0.36801095, 0.42058394,
#         0.47315693, 0.10514598, 0.57830292, 0.36801095, 0.26286496,
#         0.21029197, 0.15771898, 0.10514598, 0.        , 0.15771898]),
#  array([-2.50648852, -2.26872385, -2.03095918, -1.79319452, -1.55542985,
#         -1.31766518, -1.07990052, -0.84213585, -0.60437118, -0.36660652,
#         -0.12884185,  0.10892282,  0.34668748,  0.58445215,  0.82221682,
#          1.05998148,  1.29774615,  1.53551082,  1.77327548,  2.01104015,
#          2.24880482]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1, data2, kind='hex')

# %%
sns.jointplot(data1, data2, kind='kde', color='orange')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %%
mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = y = np.arange(-15, 15, 0.5)
X, Y = np.meshgrid(x, y)

sigma = 4
Z = np.exp(-(X**2 + Y**2)/(2*sigma**2)) / (2*np.pi*sigma**2)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)

ax.clear()
ax.plot_wireframe(X, Y, Z, rstride=2, cstride=2)

ax.clear()
ax.scatter(X, Y, Z, s=1)
